# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load grayscale image
image_path = r"C:\Users\Student\Documents\Img processing\image.jpg"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

if image is None:
    raise FileNotFoundError(f"Image not found at {image_path}")

# Apply binary thresholding
_, binary_image = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

# Define kernel for morphological operations
kernel = np.ones((5, 5), np.uint8)

# Apply morphological operations
erosion = cv2.erode(binary_image, kernel, iterations=1)
dilation = cv2.dilate(binary_image, kernel, iterations=1)
opening = cv2.morphologyEx(binary_image, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel)
gradient = cv2.morphologyEx(binary_image, cv2.MORPH_GRADIENT, kernel)

# Display results
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes[0, 0].imshow(image, cmap='gray'); axes[0, 0].set_title("Original")
axes[0, 1].imshow(binary_image, cmap='gray'); axes[0, 1].set_title("Binary Image")
axes[0, 2].imshow(erosion, cmap='gray'); axes[0, 2].set_title("Erosion")
axes[1, 0].imshow(dilation, cmap='gray'); axes[1, 0].set_title("Dilation")
axes[1, 1].imshow(opening, cmap='gray'); axes[1, 1].set_title("Opening")
axes[1, 2].imshow(closing, cmap='gray'); axes[1, 2].set_title("Closing")

for ax in axes.flatten():
    ax.axis('off')

plt.tight_layout()
plt.show()
